# %%
# https://github.com/jdepoix/youtube-transcript-api
import sys
# !{sys.executable} -m ensurepip
# %pip install --upgrade pip
# %pip install --upgrade youtube_transcript_api
# Out:
# Looking in links: /var/folders/vn/t_jql4vn7fzb9cr0qxcxdqlm0000gn/T/tmprc5z5wzq
# Requirement already satisfied: setuptools in /usr/local/miniconda3/lib/python3.7/site-packages (51.0.0.post20201207)
# Requirement already satisfied: pip in /usr/local/miniconda3/lib/python3.7/site-packages (10.0.1)
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/ab/11/2dc62c5263d9eb322f2f028f7b56cd9d096bb8988fcf82d65fa2e4057afe/pip-20.3.1-py2.py3-none-any.whl (1.5MB)
#     100% |████████████████████████████████| 1.5MB 1.9MB/s ta 0:00:01
# Installing collected packages: pip
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# Successfully installed pip-20.3.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: youtube_transcript_api in /usr/local/miniconda3/lib/python3.7/site-packages (0.3.1)
# Requirement already satisfied: requests in /usr/local/miniconda3/lib/python3.7/site-packages (from youtube_transcript_api) (2.25.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/miniconda3/lib/python3.7/site-packages (from requests->youtube_transcript_api) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/miniconda3/lib/python3.7/site-packages (from requests->youtube_transcript_api) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/miniconda3/lib/python3.7/site-packages (from requests->youtube_transcript_api) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/miniconda3/lib/python3.7/site-packages (from requests->youtube_transcript_api) (1.25.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
from youtube_transcript_api import YouTubeTranscriptApi
video_id="jLsGNENTY90"
YouTubeTranscriptApi.get_transcript(video_id, languages=['fr'])
# Out:
# [{'text': 'ces dernières semaines je me suis', 'start': 0.0, 'duration': 2.31},
#  {'text': 'plongée au coeur de la question de la',
#   'start': 0.989,
#   'duration': 2.43},
#  {'text': 'veille chez les développeurs', 'start': 2.31, 'duration': 2.94},
#  {'text': 'je me suis rendu compte que je ne',
#   'start': 3.419,
#   'duration': 3.48},
#  {'text': 'faisais pas de veille vraiment structuré',
#   'start': 5.25,
#   'duration': 3.599},
#  {'text': "et j'étais curieux de voir comment",
#   'start': 6.899,
#   'duration': 3.901},
#  {'text': 'faisait les autres après tout faire de',
#   'start': 8.849,
#   'duration': 3.511},
#  {'text': 'la veille semble être normal voire',
#   'start': 10.8,
#   'duration': 3.509},
#  {'text': "indispensable mais j'en faisais pas",
#   'start': 12.36,
#   'duration': 3.449},
#  {'text': 'tellement et ça commençait à me',
#   'start': 14.309,
#   'duration': 3.181},
#  {'text': "questionner et puis l'idée était aussi",
#   'start': 15.809,
#   'duration': 3.511},
#  {'text': "de comprendre qu'est-ce que compagnon",
#   'start': 17.49,
#   'duration': 3.57},
#  {'text': "d'artisans développeurs pouvaient",
#   'start': 19.32,
#   'duration': 3.51},
#  {'text': "apporter sur cette question j'ai donc",
#   'start': 21.06,
#   'duration': 3.479},
#  {'text': "mené une vingtaine d'interviews", 'start': 22.83, 'duration': 3.51},
#  {'text': "merci d'ailleurs à ceux qui ont joué le",
#   'start': 24.539,
#   'duration': 3.9},
#  {'text': "jeu et je vais m'appuyer tu pour",
#   'start': 26.34,
#   'duration': 4.41},
#  {'text': 'raconter ce qui suit au début je',
#   'start': 28.439,
#   'duration': 3.66},
#  {'text': 'cherchais à comprendre comment les gens',
#   'start': 30.75,
#   'duration': 2.34},
#  {'text': 'faisaient de la veille', 'start': 32.099, 'duration': 3.361},
#  {'text': 'alors oui je sais il y à tous ces',
#   'start': 33.09,
#   'duration': 4.53},
#  {'text': 'articles de blog qui explique comment le',
#   'start': 35.46,
#   'duration': 4.439},
#  {'text': 'faire mais je voulais voir comment les',
#   'start': 37.62,
#   'duration': 3.9},
#  {'text': 'gens faisait dans la vraie vie', 'start': 39.899, 'duration': 3.75},
#  {'text': 'parce que au delà de quelques conseils',
#   'start': 41.52,
#   'duration': 4.05},
#  {'text': "sur les sources et les outils j'ai pas",
#   'start': 43.649,
#   'duration': 4.5},
#  {'text': 'trouvé grand-chose et la première',
#   'start': 45.57,
#   'duration': 5.19},
#  {'text': 'surprise il y à mille manières de faire',
#   'start': 48.149,
#   'duration': 4.59},
#  {'text': 'de la veille pas deux des vingt', 'start': 50.76, 'duration': 3.84},
#  {'text': 'personnes interviewées ne le font de la',
#   'start': 52.739,
#   'duration': 4.41},
#  {'text': 'même manière alors oui on retrouve les',
#   'start': 54.6,
#   'duration': 4.77},
#  {'text': 'classiques blog et compagnie mais aussi',
#   'start': 57.149,
#   'duration': 4.441},
#  {'text': 'de nombreux médias et sources comme les',
#   'start': 59.37,
#   'duration': 3.959},
#  {'text': 'newsletters les release notes les',
#   'start': 61.59,
#   'duration': 3.719},
#  {'text': 'changelog oui oui il y en a qui lisent',
#   'start': 63.329,
#   'duration': 3.811},
#  {'text': "l'ethnologue des interactions sociales",
#   'start': 65.309,
#   'duration': 4.38},
#  {'text': "les conflits meetup c'est une explosion",
#   'start': 67.14,
#   'duration': 4.83},
#  {'text': 'de sources et de médias à ce stade',
#   'start': 69.689,
#   'duration': 3.451},
#  {'text': "autant dire que je n'étais pas très",
#   'start': 71.97,
#   'duration': 2.969},
#  {'text': "avancé à part me dire qu'en fait la",
#   'start': 73.14,
#   'duration': 3.99},
#  {'text': "veille c'était un problème pour personne",
#   'start': 74.939,
#   'duration': 4.29},
#  {'text': 'et ceux qui voulaient en faire savez',
#   'start': 77.13,
#   'duration': 3.629},
#  {'text': "très bien le faire c'est une des",
#   'start': 79.229,
#   'duration': 3.39},
#  {'text': "personnes interviewées qui m'a mis sur",
#   'start': 80.759,
#   'duration': 3.121},
#  {'text': 'la piste de quelque chose plus',
#   'start': 82.619,
#   'duration': 3.331},
#  {'text': "intéressant pendant l'interview je le",
#   'start': 83.88,
#   'duration': 4.23},
#  {'text': "sentais gêné de m'avouer qu'en fait il",
#   'start': 85.95,
#   'duration': 3.66},
#  {'text': 'ne faisait pas vraiment de veille active',
#   'start': 88.11,
#   'duration': 4.14},
#  {'text': 'y lisait quelques trucs ici et là il',
#   'start': 89.61,
#   'duration': 4.23},
#  {'text': 'aimait bien discuter technique à la',
#   'start': 92.25,
#   'duration': 3.45},
#  {'text': 'machine à café avec les collègues mais',
#   'start': 93.84,
#   'duration': 4.08},
#  {'text': 'mis à part ça rien de spécial', 'start': 95.7, 'duration': 3.599},
#  {'text': "du coup j'ai commencé à m'intéresser",
#   'start': 97.92,
#   'duration': 2.94},
#  {'text': 'plus haut pourquoi faire de la veille',
#   'start': 99.299,
#   'duration': 4.471},
#  {'text': 'que le comment faire de la bei et là ça',
#   'start': 100.86,
#   'duration': 5.1},
#  {'text': 'devient plus intéressant car il se',
#   'start': 103.77,
#   'duration': 3.66},
#  {'text': 'dégage clairement des lignes communes',
#   'start': 105.96,
#   'duration': 3.269},
#  {'text': 'dans les interviews la motivation',
#   'start': 107.43,
#   'duration': 3.27},
#  {'text': 'première affaire de la veille tourne',
#   'start': 109.229,
#   'duration': 3.42},
#  {'text': "autour de l'employabilité au sens large",
#   'start': 110.7,
#   'duration': 3.27},
#  {'text': 'que ce soit pour briguer un nouveau',
#   'start': 112.649,
#   'duration': 3.781},
#  {'text': 'poste trouvé son expertise à un prospect',
#   'start': 113.97,
#   'duration': 4.62},
#  {'text': 'convaincre un client ou tout simplement',
#   'start': 116.43,
#   'duration': 4.979},
#  {'text': "se mettre à niveau dans son job l'idée",
#   'start': 118.59,
#   'duration': 4.319},
#  {'text': "est d'être à la pointe de ce qui se fait",
#   'start': 121.409,
#   'duration': 4.471},
#  {'text': 'on a donc un premier élément de réponse',
#   'start': 122.909,
#   'duration': 4.74},
#  {'text': 'tic faire de la veille bas ça dépend',
#   'start': 125.88,
#   'duration': 4.019},
#  {'text': 'situé dans un taf tranquille qui bouge',
#   'start': 127.649,
#   'duration': 3.961},
#  {'text': 'pas trop et est bien là au pied',
#   'start': 129.899,
#   'duration': 4.141},
#  {'text': "pas forcément et c'est pas grave en fait",
#   'start': 131.61,
#   'duration': 4.379},
#  {'text': 'après il ya une autre raison qui pousse',
#   'start': 134.04,
#   'duration': 3.6},
#  {'text': 'les gens à faire de la veille le plaisir',
#   'start': 135.989,
#   'duration': 3.811},
#  {'text': 'le plaisir de découvrir quelque chose de',
#   'start': 137.64,
#   'duration': 4.41},
#  {'text': 'nouveau de se tenir au courant quand je',
#   'start': 139.8,
#   'duration': 3.48},
#  {'text': 'parlais dans eve qui lisait les tient un',
#   'start': 142.05,
#   'duration': 3.09},
#  {'text': 'blog je sentais le mec à fond dans son',
#   'start': 143.28,
#   'duration': 3.72},
#  {'text': 'truc et qui fait un vrai mort et depuis',
#   'start': 145.14,
#   'duration': 4.02},
#  {'text': 'deux ans suivait à la loupe toutes les',
#   'start': 147.0,
#   'duration': 4.739},
#  {'text': 'sorties de version et il aimait ça alors',
#   'start': 149.16,
#   'duration': 3.99},
#  {'text': 'voilà qui apporte un autre élément de',
#   'start': 151.739,
#   'duration': 1.681},
#  {'text': 'réponse', 'start': 153.15, 'duration': 2.13},
#  {'text': 'faire de la veille te permet de trouver',
#   'start': 153.42,
#   'duration': 4.289},
#  {'text': 'ou retrouver du plaisir dans ton taf',
#   'start': 155.28,
#   'duration': 4.86},
#  {'text': "si tu t'ennuies un peu boulot faire de",
#   'start': 157.709,
#   'duration': 3.721},
#  {'text': 'la veille est un bon moyen de faire',
#   'start': 160.14,
#   'duration': 3.75},
#  {'text': 'bouger tes neurones tu remarqueras que',
#   'start': 161.43,
#   'duration': 4.26},
#  {'text': 'ces deux motivations vont bien ensemble',
#   'start': 163.89,
#   'duration': 3.45},
#  {'text': 'si tu aime être à la pointe de ton',
#   'start': 165.69,
#   'duration': 3.54},
#  {'text': "domaine c'est probablement que tu es",
#   'start': 167.34,
#   'duration': 4.229},
#  {'text': 'prends du plaisir est situé prend du',
#   'start': 169.23,
#   'duration': 2.759},
#  {'text': 'plaisir', 'start': 171.569, 'duration': 2.491},
#  {'text': 'il ya probablement que ça te donne la',
#   'start': 171.989,
#   'duration': 3.901},
#  {'text': 'motivation te tenir au jus de ce qui se',
#   'start': 174.06,
#   'duration': 2.28},
#  {'text': 'fait de mieux', 'start': 175.89, 'duration': 2.459},
#  {'text': 'ces deux éléments en main en troisième',
#   'start': 176.34,
#   'duration': 3.69},
#  {'text': 'qui est un espèce de corollaire le',
#   'start': 178.349,
#   'duration': 3.601},
#  {'text': 'crédit social la veille apporte du',
#   'start': 180.03,
#   'duration': 3.33},
#  {'text': 'crédit social', 'start': 181.95, 'duration': 3.539},
#  {'text': "là encore il faut l'entendre sens large",
#   'start': 183.36,
#   'duration': 3.15},
#  {'text': 'que ce soit pour nourrir une', 'start': 185.489, 'duration': 2.791},
#  {'text': 'conversation entre tes gosses ou',
#   'start': 186.51,
#   'duration': 3.39},
#  {'text': 'embarquer les autres autour de toi dans',
#   'start': 188.28,
#   'duration': 2.25},
#  {'text': 'ton équipe', 'start': 189.9, 'duration': 2.669},
#  {'text': 'faire de la veille et la partager te',
#   'start': 190.53,
#   'duration': 3.12},
#  {'text': 'donne du crédit social', 'start': 192.569, 'duration': 3.181},
#  {'text': 'tu deviens une sorte de référence des',
#   'start': 193.65,
#   'duration': 3.869},
#  {'text': 'sujets que tu suis hélas on arrivait à',
#   'start': 195.75,
#   'duration': 3.329},
#  {'text': "quelque chose qui m'intéressait vraiment",
#   'start': 197.519,
#   'duration': 3.72},
#  {'text': 'pour compagnon on en reparle juste après',
#   'start': 199.079,
#   'duration': 3.66},
#  {'text': "parce que dans cette histoire on n'a",
#   'start': 201.239,
#   'duration': 2.97},
#  {'text': 'toujours pas explicité ce qui était',
#   'start': 202.739,
#   'duration': 3.481},
#  {'text': 'faire de la veille est en fait le',
#   'start': 204.209,
#   'duration': 3.541},
#  {'text': 'spectre est vraiment très large',
#   'start': 206.22,
#   'duration': 3.57},
#  {'text': "ça va du suivi de l'actualité à la",
#   'start': 207.75,
#   'duration': 4.41},
#  {'text': 'formation en passant par des articles de',
#   'start': 209.79,
#   'duration': 4.169},
#  {'text': 'fond sur les techno attaque où', 'start': 212.16, 'duration': 4.26},
#  {'text': "l'actualité d'elon musk et de son short",
#   'start': 213.959,
#   'duration': 3.391},
#  {'text': 'à 42 dollars', 'start': 216.42, 'duration': 2.909},
#  {'text': 'les mecs définit le prix de son produit',
#   'start': 217.35,
#   'duration': 3.93},
#  {'text': 'en fonction de son cours de bourse',
#   'start': 219.329,
#   'duration': 4.081},
#  {'text': "sérieux c'est drôle et là il ya vraiment",
#   'start': 221.28,
#   'duration': 3.09},
#  {'text': 'à boire et à manger', 'start': 223.41, 'duration': 3.27},
#  {'text': 'et finalement ce qui est consistant ce',
#   'start': 224.37,
#   'duration': 3.899},
#  {'text': "n'est pas tant le contenu que l'objectif",
#   'start': 226.68,
#   'duration': 3.389},
#  {'text': "ce qu'on retrouve également au fil des",
#   'start': 228.269,
#   'duration': 3.81},
#  {'text': "interviews c'est une sorte taxonomie de",
#   'start': 230.069,
#   'duration': 4.29},
#  {'text': 'la veille il se dégage trois niveaux de',
#   'start': 232.079,
#   'duration': 3.901},
#  {'text': "veille le niveau 3 c'est la veille",
#   'start': 234.359,
#   'duration': 3.331},
#  {'text': 'général sur le domaine elle se fait',
#   'start': 235.98,
#   'duration': 3.599},
#  {'text': 'généralement de manière passive',
#   'start': 237.69,
#   'duration': 3.24},
#  {'text': "c'est là que tu suis l'actualité du",
#   'start': 239.579,
#   'duration': 3.331},
#  {'text': "métier de ton secteur d'activité ou",
#   'start': 240.93,
#   'duration': 3.63},
#  {'text': 'encore les sujets périphériques qui te',
#   'start': 242.91,
#   'duration': 3.81},
#  {'text': "plaisent c'est souvent fait en plus",
#   'start': 244.56,
#   'duration': 2.88},
#  {'text': "d'autres choses", 'start': 246.72, 'duration': 2.609},
#  {'text': 'par exemple tu peux écouter un podcast',
#   'start': 247.44,
#   'duration': 4.36},
#  {'text': 'août en jardinant ou en conduisant',
#   'start': 249.329,
#   'duration': 3.641},
#  {'text': "c'est typiquement le niveau des coudes",
#   'start': 251.8,
#   'duration': 2.85},
#  {'text': 'que les gens vont avoir avec le podcast',
#   'start': 252.97,
#   'duration': 3.36},
#  {'text': 'artisans développeurs et plus', 'start': 254.65, 'duration': 3.45},
#  {'text': 'généralement avec les sources qui',
#   'start': 256.33,
#   'duration': 3.6},
#  {'text': "s'accommode de l'audio furent ensuite il",
#   'start': 258.1,
#   'duration': 3.3},
#  {'text': "ya le niveau 2 c'est tout ce qui",
#   'start': 259.93,
#   'duration': 3.48},
#  {'text': "concerne ta stack de travail c'est un",
#   'start': 261.4,
#   'duration': 4.14},
#  {'text': 'stack de base tourne sur une note plus',
#   'start': 263.41,
#   'duration': 4.2},
#  {'text': 'vu tu vas typiquement regarder de près',
#   'start': 265.54,
#   'duration': 4.23},
#  {'text': "ce qu'il s'y passe si tu aimes le craft",
#   'start': 267.61,
#   'duration': 3.75},
#  {'text': 'tu vas suivre les tendances te nourrir',
#   'start': 269.77,
#   'duration': 3.33},
#  {'text': 'des mots clés que tu trouveras pour',
#   'start': 271.36,
#   'duration': 3.93},
#  {'text': 'aller creuser ensuite comme par exemple',
#   'start': 273.1,
#   'duration': 4.47},
#  {'text': 'des ddc qrs on est sur une écoute plus',
#   'start': 275.29,
#   'duration': 4.53},
#  {'text': 'active mais qui reste légère certes un',
#   'start': 277.57,
#   'duration': 3.93},
#  {'text': 'épisode du podcast artisans développeurs',
#   'start': 279.82,
#   'duration': 3.18},
#  {'text': "vont correspondre à ce niveau d'écouté",
#   'start': 281.5,
#   'duration': 3.66},
#  {'text': 'tout un ensemble de blogs sont à ce',
#   'start': 283.0,
#   'duration': 2.55},
#  {'text': 'niveau', 'start': 285.16, 'duration': 2.52},
#  {'text': "l'idée là et 2 et que ça reste court",
#   'start': 285.55,
#   'duration': 3.63},
#  {'text': 'quand même quelques minutes pour',
#   'start': 287.68,
#   'duration': 3.39},
#  {'text': 'consommer le contenu enfin il ya le',
#   'start': 289.18,
#   'duration': 3.6},
#  {'text': 'niveau 1 et là on passe sur un niveau',
#   'start': 291.07,
#   'duration': 3.72},
#  {'text': "d'études plus profond c'est le moment où",
#   'start': 292.78,
#   'duration': 3.93},
#  {'text': 'tu va étudier plus en profondeur et',
#   'start': 294.79,
#   'duration': 2.73},
#  {'text': 'tester des choses', 'start': 296.71, 'duration': 2.97},
#  {'text': 'par exemple il se passe quoi si tu mets',
#   'start': 297.52,
#   'duration': 4.2},
#  {'text': 'à jour ton frère mort coeur tiens une',
#   'start': 299.68,
#   'duration': 3.84},
#  {'text': "nouvelle version majeure d'un outil que",
#   'start': 301.72,
#   'duration': 3.75},
#  {'text': 'tu avais danton radar soeur parfait',
#   'start': 303.52,
#   'duration': 3.9},
#  {'text': "c'est l'occasion de faire un prototype 2",
#   'start': 305.47,
#   'duration': 3.99},
#  {'text': 'to do list ou de crm basique', 'start': 307.42, 'duration': 3.87},
#  {'text': "ce qui est bien avec le crm c'est le cas",
#   'start': 309.46,
#   'duration': 3.24},
#  {'text': 'des usages restent simples et tu peux',
#   'start': 311.29,
#   'duration': 3.03},
#  {'text': 'aborder plein de choses comme la gestion',
#   'start': 312.7,
#   'duration': 3.57},
#  {'text': 'des relations entre objets tout temps',
#   'start': 314.32,
#   'duration': 3.75},
#  {'text': "ramifiant les cas d'usagés besoin on est",
#   'start': 316.27,
#   'duration': 3.21},
#  {'text': 'là sur un niveau qui demandent plus',
#   'start': 318.07,
#   'duration': 4.02},
#  {'text': "d'engagement et un travail actif on ne",
#   'start': 319.48,
#   'duration': 3.36},
#  {'text': "fait rien d'autre", 'start': 322.09, 'duration': 2.37},
#  {'text': 'pendant ce temps et le cerveau est comme',
#   'start': 322.84,
#   'duration': 3.36},
#  {'text': "une éponge c'est typiquement le niveau",
#   'start': 324.46,
#   'duration': 4.05},
#  {'text': 'des formations des livres ou encore de',
#   'start': 326.2,
#   'duration': 4.14},
#  {'text': 'certains articles de blog bien pointues',
#   'start': 328.51,
#   'duration': 3.75},
#  {'text': 'et danse alors revenons-en à ce fameux',
#   'start': 330.34,
#   'duration': 2.67},
#  {'text': 'crédit social', 'start': 332.26, 'duration': 2.61},
#  {'text': "je t'ai dit tout à l'heure que ça avait",
#   'start': 333.01,
#   'duration': 3.33},
#  {'text': 'attiré mon attention par rapport à',
#   'start': 334.87,
#   'duration': 3.48},
#  {'text': 'compagnon on a commencé la rubrique',
#   'start': 336.34,
#   'duration': 4.32},
#  {'text': 'veille en intégrant automatiquement les',
#   'start': 338.35,
#   'duration': 4.02},
#  {'text': "contenus d'artisans développeurs et puis",
#   'start': 340.66,
#   'duration': 2.43},
#  {'text': 'on se dit que ça pouvait être', 'start': 342.37, 'duration': 2.1},
#  {'text': "intéressant de l'ouvrir plus largement",
#   'start': 343.09,
#   'duration': 3.45},
#  {'text': 'et partager les ressources qui nous',
#   'start': 344.47,
#   'duration': 3.09},
#  {'text': 'semble intéressante', 'start': 346.54, 'duration': 3.42},
#  {'text': 'après tout le web regorge de pépites',
#   'start': 347.56,
#   'duration': 4.68},
#  {'text': 'alors pourquoi rester replier sur soi',
#   'start': 349.96,
#   'duration': 3.63},
#  {'text': 'rapidement je me suis rendu compte de',
#   'start': 352.24,
#   'duration': 3.27},
#  {'text': "deux choses d'abord l'activité de veille",
#   'start': 353.59,
#   'duration': 2.76},
#  {'text': 'est très solitaire', 'start': 355.51, 'duration': 3.12},
#  {'text': "j'ai eu plusieurs témoignages de dave",
#   'start': 356.35,
#   'duration': 4.26},
#  {'text': "qui montrait clairement qu'il faisait sa",
#   'start': 358.63,
#   'duration': 3.87},
#  {'text': "seule et qu'il ait essayé ensuite de",
#   'start': 360.61,
#   'duration': 3.24},
#  {'text': 'partager leurs découvertes avec les',
#   'start': 362.5,
#   'duration': 3.3},
#  {'text': 'autres et ce avec plus ou moins',
#   'start': 363.85,
#   'duration': 4.14},
#  {'text': "d'enthousiasmé de succès autour d'eux",
#   'start': 365.8,
#   'duration': 3.66},
#  {'text': 'pour peu que les autres membres de',
#   'start': 367.99,
#   'duration': 3.66},
#  {'text': "l'équipe ne partage pas vraiment son",
#   'start': 369.46,
#   'duration': 3.27},
#  {'text': "plaisir d'être au travail", 'start': 371.65, 'duration': 2.94},
#  {'text': "le sentiment de solitude n'était que",
#   'start': 372.73,
#   'duration': 4.02},
#  {'text': 'renforcer alors pourquoi pas faire ça',
#   'start': 374.59,
#   'duration': 3.99},
#  {'text': 'veille en meute et là on arrive au',
#   'start': 376.75,
#   'duration': 3.81},
#  {'text': 'second point le web regorge de', 'start': 378.58, 'duration': 3.01},
#  {'text': 'ressources', 'start': 380.56, 'duration': 2.2},
#  {'text': 'en particulier de ressources', 'start': 381.59, 'duration': 3.42},
#  {'text': 'francophones mal valorisées et pourtant',
#   'start': 382.76,
#   'duration': 4.05},
#  {'text': "certaines sont de vraies mines d'or de",
#   'start': 385.01,
#   'duration': 3.66},
#  {'text': "connaissances ok l'anglais la langue",
#   'start': 386.81,
#   'duration': 4.05},
#  {'text': 'maîtresse de notre domaine est alors est',
#   'start': 388.67,
#   'duration': 3.45},
#  {'text': "ce qu'il faut pour autant abdiquer et",
#   'start': 390.86,
#   'duration': 2.85},
#  {'text': "s'interdire de produire du contenu de",
#   'start': 392.12,
#   'duration': 3.48},
#  {'text': 'qualité en français en plus le contenu',
#   'start': 393.71,
#   'duration': 4.05},
#  {'text': 'et la souvent mais le scénario est',
#   'start': 395.6,
#   'duration': 4.08},
#  {'text': 'toujours le même un dev a envie de',
#   'start': 397.76,
#   'duration': 3.39},
#  {'text': 'partager les sujets qui le passionnent',
#   'start': 399.68,
#   'duration': 3.99},
#  {'text': 'du moment il va peut-être même se jeter',
#   'start': 401.15,
#   'duration': 3.84},
#  {'text': 'à fond sur un point est passé des',
#   'start': 403.67,
#   'duration': 3.78},
#  {'text': "dizaines d'heures à potasser et rédigé",
#   'start': 404.99,
#   'duration': 3.27},
#  {'text': 'certains articles', 'start': 407.45, 'duration': 2.7},
#  {'text': 'et puis la vie va reprendre le dessus',
#   'start': 408.26,
#   'duration': 3.54},
#  {'text': 'nouveau taaf un enfant une nouvelle',
#   'start': 410.15,
#   'duration': 4.2},
#  {'text': 'maison un mariage auront raison de sa',
#   'start': 411.8,
#   'duration': 4.56},
#  {'text': 'motivation et émettra son blog de côté',
#   'start': 414.35,
#   'duration': 3.84},
#  {'text': "et franchement c'est bien normal ils",
#   'start': 416.36,
#   'duration': 3.36},
#  {'text': "n'attendront pas le niveau pour que",
#   'start': 418.19,
#   'duration': 3.33},
#  {'text': 'google donne les mettre en valeur et le',
#   'start': 419.72,
#   'duration': 4.05},
#  {'text': 'contenu finira dans un joli blog perdu',
#   'start': 421.52,
#   'duration': 4.41},
#  {'text': 'sa marche pareil pour youtube où les',
#   'start': 423.77,
#   'duration': 3.51},
#  {'text': 'podcasts il faut reconnaître que',
#   'start': 425.93,
#   'duration': 3.03},
#  {'text': 'produire un média de manière continue',
#   'start': 427.28,
#   'duration': 3.72},
#  {'text': 'sur la durée est une vraie gageure',
#   'start': 428.96,
#   'duration': 4.56},
#  {'text': "j'en sais quelque chose avec plus de 250",
#   'start': 431.0,
#   'duration': 4.41},
#  {'text': '6 épisodes de podcasts je sais le',
#   'start': 433.52,
#   'duration': 4.02},
#  {'text': 'travail que ça représente de produire de',
#   'start': 435.41,
#   'duration': 3.84},
#  {'text': 'manière assidue du contenu on a donc',
#   'start': 437.54,
#   'duration': 3.39},
#  {'text': "d'un côté des devs qui se sentent un peu",
#   'start': 439.25,
#   'duration': 3.81},
#  {'text': 'seuls dans leur veille ou même dans leur',
#   'start': 440.93,
#   'duration': 3.6},
#  {'text': 'quotidien quand bien même ils sont en',
#   'start': 443.06,
#   'duration': 3.21},
#  {'text': "équipe et d'un autre de belles", 'start': 444.53, 'duration': 3.69},
#  {'text': 'ressources pas toujours facile à trouver',
#   'start': 446.27,
#   'duration': 3.84},
#  {'text': "t'as pas un truc à faire là et s'ils ont",
#   'start': 448.22,
#   'duration': 3.54},
#  {'text': 'partagé entre nous les bonnes ressources',
#   'start': 450.11,
#   'duration': 4.02},
#  {'text': "l'idée serait d'aller au delà du simple",
#   'start': 451.76,
#   'duration': 4.26},
#  {'text': "partage c'est un bon début", 'start': 454.13, 'duration': 3.87},
#  {'text': "et c'est déjà très bien mais on pourrait",
#   'start': 456.02,
#   'duration': 3.42},
#  {'text': "faire mieux je m'explique", 'start': 458.0, 'duration': 2.79},
#  {'text': 'la production de contenus a', 'start': 459.44, 'duration': 3.6},
#  {'text': 'littéralement explosé la quantité de',
#   'start': 460.79,
#   'duration': 4.11},
#  {'text': "vidéos articles qu'on fout je ne sais",
#   'start': 463.04,
#   'duration': 3.87},
#  {'text': 'quoi encore que je trouve intéressant',
#   'start': 464.9,
#   'duration': 4.62},
#  {'text': 'dépasse largement ma capacité à les',
#   'start': 466.91,
#   'duration': 3.75},
#  {'text': 'étudier', 'start': 469.52, 'duration': 2.67},
#  {'text': 'du coup comment faire pour savoir',
#   'start': 470.66,
#   'duration': 2.76},
#  {'text': 'quelles ressources vont vraiment',
#   'start': 472.19,
#   'duration': 3.54},
#  {'text': "m'intéresser comment prioriser c'est là",
#   'start': 473.42,
#   'duration': 4.38},
#  {'text': 'que les change devient intéressant quand',
#   'start': 475.73,
#   'duration': 3.69},
#  {'text': 'je partage une ressource que je trouve',
#   'start': 477.8,
#   'duration': 3.39},
#  {'text': "intéressante quelqu'un d'autre peut en",
#   'start': 479.42,
#   'duration': 3.51},
#  {'text': 'résumé les idées principales sous forme',
#   'start': 481.19,
#   'duration': 3.63},
#  {'text': 'de texte ou même de my maps un autre',
#   'start': 482.93,
#   'duration': 3.39},
#  {'text': 'peut expliquer ce que le sujet abordé',
#   'start': 484.82,
#   'duration': 3.81},
#  {'text': "lui a apporté et le bénéfice qu'il en a",
#   'start': 486.32,
#   'duration': 4.2},
#  {'text': 'retiré tout ça vient nourrir les changes',
#   'start': 488.63,
#   'duration': 4.17},
#  {'text': 'permet à chacun de partager son point de',
#   'start': 490.52,
#   'duration': 4.05},
#  {'text': 'vue et de prioriser telle ou telle',
#   'start': 492.8,
#   'duration': 2.37},
#  {'text': 'ressource', 'start': 494.57, 'duration': 2.34},
#  {'text': "c'est une très bonne manière pour les",
#   'start': 495.17,
#   'duration': 3.3},
#  {'text': "plus expérimentés d'encre et leurs",
#   'start': 496.91,
#   'duration': 3.42},
#  {'text': 'connaissances car les résumés est un',
#   'start': 498.47,
#   'duration': 3.99},
#  {'text': "excellent exercice pour ça et c'est un",
#   'start': 500.33,
#   'duration': 3.99},
#  {'text': 'très bon moyen pour les débutants de',
#   'start': 502.46,
#   'duration': 3.3},
#  {'text': "bénéficier des retours d'autres",
#   'start': 504.32,
#   'duration': 3.15},
#  {'text': 'personnes qui les guideront dans leur',
#   'start': 505.76,
#   'duration': 2.34},
#  {'text': 'exploration', 'start': 507.47, 'duration': 2.04},
#  {'text': "c'est autour de ces idées principales",
#   'start': 508.1,
#   'duration': 3.82},
#  {'text': "que l'on a fait évoluer compagnon",
#   'start': 509.51,
#   'duration': 3.61},
#  {'text': 'tu peux donc maintenant non seulement',
#   'start': 511.92,
#   'duration': 2.94},
#  {'text': 'partager les ressources qui te semble',
#   'start': 513.12,
#   'duration': 3.45},
#  {'text': 'plus intéressante mais tu peux aussi',
#   'start': 514.86,
#   'duration': 4.23},
#  {'text': 'échanger autour et votez pour celle qui',
#   'start': 516.57,
#   'duration': 4.62},
#  {'text': 'te semble plus pertinent on a même créé',
#   'start': 519.09,
#   'duration': 3.87},
#  {'text': "un profil personnel qui permet d'en dire",
#   'start': 521.19,
#   'duration': 3.36},
#  {'text': "un peu plus sur ses centres d'intérêt",
#   'start': 522.96,
#   'duration': 3.12},
#  {'text': 'afin de faire connaissance plus',
#   'start': 524.55,
#   'duration': 3.27},
#  {'text': 'facilement tout ça est disponible sur',
#   'start': 526.08,
#   'duration': 3.51},
#  {'text': 'compagnon point artisans développeurs',
#   'start': 527.82,
#   'duration': 3.66},
#  {'text': 'point fr alors si tu en es là à',
#   'start': 529.59,
#   'duration': 4.29},
#  {'text': "m'écouter je te lance un défi partagent",
#   'start': 531.48,
#   'duration': 3.78},
#  {'text': 'au moins une ressource que tu trouves',
#   'start': 533.88,
#   'duration': 3.51},
#  {'text': 'top cette vidéo devrait dépasser avec le',
#   'start': 535.26,
#   'duration': 4.62},
#  {'text': 'temps les 1000 vue si même 20% dès gens',
#   'start': 537.39,
#   'duration': 4.23},
#  {'text': 'qui vont arriver là partage ne serait ce',
#   'start': 539.88,
#   'duration': 2.7},
#  {'text': "qu'une bonne ressource", 'start': 541.62, 'duration': 3.03},
#  {'text': 'ça permettra de dynamiser la communauté',
#   'start': 542.58,
#   'duration': 3.99},
#  {'text': 'et nourrir une boucle vertueuse',
#   'start': 544.65,
#   'duration': 3.63},
#  {'text': "bien sûr je suis à l'affût ton feedback",
#   'start': 546.57,
#   'duration': 4.26},
#  {'text': 'compagnon est encore très jeune et on',
#   'start': 548.28,
#   'duration': 3.95},
#  {'text': 'écoute attentivement les retours',
#   'start': 550.83,
#   'duration': 3.24},
#  {'text': "plusieurs feature en sont d'ailleurs",
#   'start': 552.23,
#   'duration': 3.4},
#  {'text': 'directement issue pour nous faire un',
#   'start': 554.07,
#   'duration': 2.16},
#  {'text': 'retour', 'start': 555.63, 'duration': 1.5},
#  {'text': "rien de plus simple tu m'envoies un",
#   'start': 556.23,
#   'duration': 2.76},
#  {'text': 'email benoît robin artisans développeurs',
#   'start': 557.13,
#   'duration': 4.29},
#  {'text': 'point fr ou simplement indiqué', 'start': 558.99, 'duration': 4.29},
#  {'text': "suggestions directement dans l'airé 19",
#   'start': 561.42,
#   'duration': 4.2},
#  {'text': 'deux compagnons temps compagnon tu peux',
#   'start': 563.28,
#   'duration': 3.69},
#  {'text': 'aussi tout simplement ajouter un',
#   'start': 565.62,
#   'duration': 1.92},
#  {'text': 'commentaire', 'start': 566.97, 'duration': 2.31},
#  {'text': 'histoire de simplifier la vie tu',
#   'start': 567.54,
#   'duration': 3.27},
#  {'text': 'trouveras bien sûr le lien vers',
#   'start': 569.28,
#   'duration': 2.82},
#  {'text': 'compagnon dans la description', 'start': 570.81, 'duration': 3.06},
#  {'text': "j'espère que tu seras enrichi de ce",
#   'start': 572.1,
#   'duration': 4.89},
#  {'text': 'moment passé ensemble pense at abonné et',
#   'start': 573.87,
#   'duration': 5.58},
#  {'text': 'je te dis merci merci pour ton écoute et',
#   'start': 576.99,
#   'duration': 4.82},
#  {'text': 'à bientôt', 'start': 579.45, 'duration': 2.36}]
