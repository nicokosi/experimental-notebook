# %%
# https://github.com/jdepoix/youtube-transcript-api
import sys
# !{sys.executable} -m ensurepip
# %pip install --upgrade pip
# %pip install --upgrade youtube_transcript_api
# Out:
# Looking in links: /var/folders/vn/t_jql4vn7fzb9cr0qxcxdqlm0000gn/T/tmprc5z5wzq
# Requirement already satisfied: setuptools in /usr/local/miniconda3/lib/python3.7/site-packages (51.0.0.post20201207)
# Requirement already satisfied: pip in /usr/local/miniconda3/lib/python3.7/site-packages (10.0.1)
# Collecting pip
#   Downloading https://files.pythonhosted.org/packages/ab/11/2dc62c5263d9eb322f2f028f7b56cd9d096bb8988fcf82d65fa2e4057afe/pip-20.3.1-py2.py3-none-any.whl (1.5MB)
#     100% |████████████████████████████████| 1.5MB 1.9MB/s ta 0:00:01
# Installing collected packages: pip
#   Found existing installation: pip 10.0.1
#     Uninstalling pip-10.0.1:
#       Successfully uninstalled pip-10.0.1
# Successfully installed pip-20.3.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: youtube_transcript_api in /usr/local/miniconda3/lib/python3.7/site-packages (0.3.1)
# Requirement already satisfied: requests in /usr/local/miniconda3/lib/python3.7/site-packages (from youtube_transcript_api) (2.25.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/miniconda3/lib/python3.7/site-packages (from requests->youtube_transcript_api) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/miniconda3/lib/python3.7/site-packages (from requests->youtube_transcript_api) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/miniconda3/lib/python3.7/site-packages (from requests->youtube_transcript_api) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/miniconda3/lib/python3.7/site-packages (from requests->youtube_transcript_api) (1.25.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
from youtube_transcript_api import YouTubeTranscriptApi
video_id="jLsGNENTY90"
transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['fr'])
phrases = ""
for phrase in transcript:
    phrases += phrase['text'] + "\n"
print(phrases)
# Out:
# ces dernières semaines je me suis
# plongée au coeur de la question de la
# veille chez les développeurs
# je me suis rendu compte que je ne
# faisais pas de veille vraiment structuré
# et j'étais curieux de voir comment
# faisait les autres après tout faire de
# la veille semble être normal voire
# indispensable mais j'en faisais pas
# tellement et ça commençait à me
# questionner et puis l'idée était aussi
# de comprendre qu'est-ce que compagnon
# d'artisans développeurs pouvaient
# apporter sur cette question j'ai donc
# mené une vingtaine d'interviews
# merci d'ailleurs à ceux qui ont joué le
# jeu et je vais m'appuyer tu pour
# raconter ce qui suit au début je
# cherchais à comprendre comment les gens
# faisaient de la veille
# alors oui je sais il y à tous ces
# articles de blog qui explique comment le
# faire mais je voulais voir comment les
# gens faisait dans la vraie vie
# parce que au delà de quelques conseils
# sur les sources et les outils j'ai pas
# trouvé grand-chose et la première
# surprise il y à mille manières de faire
# de la veille pas deux des vingt
# personnes interviewées ne le font de la
# même manière alors oui on retrouve les
# classiques blog et compagnie mais aussi
# de nombreux médias et sources comme les
# newsletters les release notes les
# changelog oui oui il y en a qui lisent
# l'ethnologue des interactions sociales
# les conflits meetup c'est une explosion
# de sources et de médias à ce stade
# autant dire que je n'étais pas très
# avancé à part me dire qu'en fait la
# veille c'était un problème pour personne
# et ceux qui voulaient en faire savez
# très bien le faire c'est une des
# personnes interviewées qui m'a mis sur
# la piste de quelque chose plus
# intéressant pendant l'interview je le
# sentais gêné de m'avouer qu'en fait il
# ne faisait pas vraiment de veille active
# y lisait quelques trucs ici et là il
# aimait bien discuter technique à la
# machine à café avec les collègues mais
# mis à part ça rien de spécial
# du coup j'ai commencé à m'intéresser
# plus haut pourquoi faire de la veille
# que le comment faire de la bei et là ça
# devient plus intéressant car il se
# dégage clairement des lignes communes
# dans les interviews la motivation
# première affaire de la veille tourne
# autour de l'employabilité au sens large
# que ce soit pour briguer un nouveau
# poste trouvé son expertise à un prospect
# convaincre un client ou tout simplement
# se mettre à niveau dans son job l'idée
# est d'être à la pointe de ce qui se fait
# on a donc un premier élément de réponse
# tic faire de la veille bas ça dépend
# situé dans un taf tranquille qui bouge
# pas trop et est bien là au pied
# pas forcément et c'est pas grave en fait
# après il ya une autre raison qui pousse
# les gens à faire de la veille le plaisir
# le plaisir de découvrir quelque chose de
# nouveau de se tenir au courant quand je
# parlais dans eve qui lisait les tient un
# blog je sentais le mec à fond dans son
# truc et qui fait un vrai mort et depuis
# deux ans suivait à la loupe toutes les
# sorties de version et il aimait ça alors
# voilà qui apporte un autre élément de
# réponse
# faire de la veille te permet de trouver
# ou retrouver du plaisir dans ton taf
# si tu t'ennuies un peu boulot faire de
# la veille est un bon moyen de faire
# bouger tes neurones tu remarqueras que
# ces deux motivations vont bien ensemble
# si tu aime être à la pointe de ton
# domaine c'est probablement que tu es
# prends du plaisir est situé prend du
# plaisir
# il ya probablement que ça te donne la
# motivation te tenir au jus de ce qui se
# fait de mieux
# ces deux éléments en main en troisième
# qui est un espèce de corollaire le
# crédit social la veille apporte du
# crédit social
# là encore il faut l'entendre sens large
# que ce soit pour nourrir une
# conversation entre tes gosses ou
# embarquer les autres autour de toi dans
# ton équipe
# faire de la veille et la partager te
# donne du crédit social
# tu deviens une sorte de référence des
# sujets que tu suis hélas on arrivait à
# quelque chose qui m'intéressait vraiment
# pour compagnon on en reparle juste après
# parce que dans cette histoire on n'a
# toujours pas explicité ce qui était
# faire de la veille est en fait le
# spectre est vraiment très large
# ça va du suivi de l'actualité à la
# formation en passant par des articles de
# fond sur les techno attaque où
# l'actualité d'elon musk et de son short
# à 42 dollars
# les mecs définit le prix de son produit
# en fonction de son cours de bourse
# sérieux c'est drôle et là il ya vraiment
# à boire et à manger
# et finalement ce qui est consistant ce
# n'est pas tant le contenu que l'objectif
# ce qu'on retrouve également au fil des
# interviews c'est une sorte taxonomie de
# la veille il se dégage trois niveaux de
# veille le niveau 3 c'est la veille
# général sur le domaine elle se fait
# généralement de manière passive
# c'est là que tu suis l'actualité du
# métier de ton secteur d'activité ou
# encore les sujets périphériques qui te
# plaisent c'est souvent fait en plus
# d'autres choses
# par exemple tu peux écouter un podcast
# août en jardinant ou en conduisant
# c'est typiquement le niveau des coudes
# que les gens vont avoir avec le podcast
# artisans développeurs et plus
# généralement avec les sources qui
# s'accommode de l'audio furent ensuite il
# ya le niveau 2 c'est tout ce qui
# concerne ta stack de travail c'est un
# stack de base tourne sur une note plus
# vu tu vas typiquement regarder de près
# ce qu'il s'y passe si tu aimes le craft
# tu vas suivre les tendances te nourrir
# des mots clés que tu trouveras pour
# aller creuser ensuite comme par exemple
# des ddc qrs on est sur une écoute plus
# active mais qui reste légère certes un
# épisode du podcast artisans développeurs
# vont correspondre à ce niveau d'écouté
# tout un ensemble de blogs sont à ce
# niveau
# l'idée là et 2 et que ça reste court
# quand même quelques minutes pour
# consommer le contenu enfin il ya le
# niveau 1 et là on passe sur un niveau
# d'études plus profond c'est le moment où
# tu va étudier plus en profondeur et
# tester des choses
# par exemple il se passe quoi si tu mets
# à jour ton frère mort coeur tiens une
# nouvelle version majeure d'un outil que
# tu avais danton radar soeur parfait
# c'est l'occasion de faire un prototype 2
# to do list ou de crm basique
# ce qui est bien avec le crm c'est le cas
# des usages restent simples et tu peux
# aborder plein de choses comme la gestion
# des relations entre objets tout temps
# ramifiant les cas d'usagés besoin on est
# là sur un niveau qui demandent plus
# d'engagement et un travail actif on ne
# fait rien d'autre
# pendant ce temps et le cerveau est comme
# une éponge c'est typiquement le niveau
# des formations des livres ou encore de
# certains articles de blog bien pointues
# et danse alors revenons-en à ce fameux
# crédit social
# je t'ai dit tout à l'heure que ça avait
# attiré mon attention par rapport à
# compagnon on a commencé la rubrique
# veille en intégrant automatiquement les
# contenus d'artisans développeurs et puis
# on se dit que ça pouvait être
# intéressant de l'ouvrir plus largement
# et partager les ressources qui nous
# semble intéressante
# après tout le web regorge de pépites
# alors pourquoi rester replier sur soi
# rapidement je me suis rendu compte de
# deux choses d'abord l'activité de veille
# est très solitaire
# j'ai eu plusieurs témoignages de dave
# qui montrait clairement qu'il faisait sa
# seule et qu'il ait essayé ensuite de
# partager leurs découvertes avec les
# autres et ce avec plus ou moins
# d'enthousiasmé de succès autour d'eux
# pour peu que les autres membres de
# l'équipe ne partage pas vraiment son
# plaisir d'être au travail
# le sentiment de solitude n'était que
# renforcer alors pourquoi pas faire ça
# veille en meute et là on arrive au
# second point le web regorge de
# ressources
# en particulier de ressources
# francophones mal valorisées et pourtant
# certaines sont de vraies mines d'or de
# connaissances ok l'anglais la langue
# maîtresse de notre domaine est alors est
# ce qu'il faut pour autant abdiquer et
# s'interdire de produire du contenu de
# qualité en français en plus le contenu
# et la souvent mais le scénario est
# toujours le même un dev a envie de
# partager les sujets qui le passionnent
# du moment il va peut-être même se jeter
# à fond sur un point est passé des
# dizaines d'heures à potasser et rédigé
# certains articles
# et puis la vie va reprendre le dessus
# nouveau taaf un enfant une nouvelle
# maison un mariage auront raison de sa
# motivation et émettra son blog de côté
# et franchement c'est bien normal ils
# n'attendront pas le niveau pour que
# google donne les mettre en valeur et le
# contenu finira dans un joli blog perdu
# sa marche pareil pour youtube où les
# podcasts il faut reconnaître que
# produire un média de manière continue
# sur la durée est une vraie gageure
# j'en sais quelque chose avec plus de 250
# 6 épisodes de podcasts je sais le
# travail que ça représente de produire de
# manière assidue du contenu on a donc
# d'un côté des devs qui se sentent un peu
# seuls dans leur veille ou même dans leur
# quotidien quand bien même ils sont en
# équipe et d'un autre de belles
# ressources pas toujours facile à trouver
# t'as pas un truc à faire là et s'ils ont
# partagé entre nous les bonnes ressources
# l'idée serait d'aller au delà du simple
# partage c'est un bon début
# et c'est déjà très bien mais on pourrait
# faire mieux je m'explique
# la production de contenus a
# littéralement explosé la quantité de
# vidéos articles qu'on fout je ne sais
# quoi encore que je trouve intéressant
# dépasse largement ma capacité à les
# étudier
# du coup comment faire pour savoir
# quelles ressources vont vraiment
# m'intéresser comment prioriser c'est là
# que les change devient intéressant quand
# je partage une ressource que je trouve
# intéressante quelqu'un d'autre peut en
# résumé les idées principales sous forme
# de texte ou même de my maps un autre
# peut expliquer ce que le sujet abordé
# lui a apporté et le bénéfice qu'il en a
# retiré tout ça vient nourrir les changes
# permet à chacun de partager son point de
# vue et de prioriser telle ou telle
# ressource
# c'est une très bonne manière pour les
# plus expérimentés d'encre et leurs
# connaissances car les résumés est un
# excellent exercice pour ça et c'est un
# très bon moyen pour les débutants de
# bénéficier des retours d'autres
# personnes qui les guideront dans leur
# exploration
# c'est autour de ces idées principales
# que l'on a fait évoluer compagnon
# tu peux donc maintenant non seulement
# partager les ressources qui te semble
# plus intéressante mais tu peux aussi
# échanger autour et votez pour celle qui
# te semble plus pertinent on a même créé
# un profil personnel qui permet d'en dire
# un peu plus sur ses centres d'intérêt
# afin de faire connaissance plus
# facilement tout ça est disponible sur
# compagnon point artisans développeurs
# point fr alors si tu en es là à
# m'écouter je te lance un défi partagent
# au moins une ressource que tu trouves
# top cette vidéo devrait dépasser avec le
# temps les 1000 vue si même 20% dès gens
# qui vont arriver là partage ne serait ce
# qu'une bonne ressource
# ça permettra de dynamiser la communauté
# et nourrir une boucle vertueuse
# bien sûr je suis à l'affût ton feedback
# compagnon est encore très jeune et on
# écoute attentivement les retours
# plusieurs feature en sont d'ailleurs
# directement issue pour nous faire un
# retour
# rien de plus simple tu m'envoies un
# email benoît robin artisans développeurs
# point fr ou simplement indiqué
# suggestions directement dans l'airé 19
# deux compagnons temps compagnon tu peux
# aussi tout simplement ajouter un
# commentaire
# histoire de simplifier la vie tu
# trouveras bien sûr le lien vers
# compagnon dans la description
# j'espère que tu seras enrichi de ce
# moment passé ensemble pense at abonné et
# je te dis merci merci pour ton écoute et
# à bientôt
